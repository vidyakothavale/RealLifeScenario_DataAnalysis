# %%
import pandas as pd
import numpy as np

# %%
# x for ecommmerce company 

X_order=pd.read_excel("Company X - Order Report.xlsx")
#X_order

X_pincodeZone=pd.read_excel(r"Company X - Pincode Zones.xlsx")
#X_pincodeZone

X_skuMaster=pd.read_excel(r"Company X - SKU Master.xlsx")
#X_skuMaster

couriercomp_invoice=pd.read_excel(r"Courier Company - Invoice.xlsx")
#couriercomp_invoice

couriercomp_Rate=pd.read_excel(r"Courier Company - Rates.xlsx")
#couriercomp_Rate

# %% [markdown]
# ### company Report

# %%
X_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ExternOrderNo  400 non-null    int64
#  1   SKU            400 non-null    object
#  2   Order Qty      400 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 9.5+ KB

# %%
X_order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ExternOrderNo  400 non-null    int64
#  1   SKU            400 non-null    object
#  2   Order Qty      400 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 9.5+ KB

# %%
X_order.describe()
# Out:
#        ExternOrderNo   Order Qty
# count   4.000000e+02  400.000000
# mean    2.001811e+09    1.297500
# std     5.187698e+03    0.919842
# min     2.001806e+09    1.000000
# 25%     2.001807e+09    1.000000
# 50%     2.001809e+09    1.000000
# 75%     2.001812e+09    1.000000
# max     2.001827e+09    8.000000

# %%
X_order
# Out:
#      ExternOrderNo            SKU  Order Qty
# 0       2001827036  8904223818706        1.0
# 1       2001827036  8904223819093        1.0
# 2       2001827036  8904223819109        1.0
# 3       2001827036  8904223818430        1.0
# 4       2001827036  8904223819277        1.0
# ..             ...            ...        ...
# 395     2001806229  8904223818942        1.0
# 396     2001806229  8904223818850        1.0
# 397     2001806226  8904223818850        2.0
# 398     2001806210  8904223816214        1.0
# 399     2001806210  8904223818874        1.0
#
# [400 rows x 3 columns]

# %%
X_order=pd.merge(X_order,X_skuMaster,on='SKU')
X_order
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)
# 0       2001827036  8904223818706        1.0         127
# 1       2001821995  8904223818706        1.0         127
# 2       2001819252  8904223818706        1.0         127
# 3       2001816996  8904223818706        1.0         127
# 4       2001814580  8904223818706        1.0         127
# ..             ...            ...        ...         ...
# 396     2001806616  8904223819123        1.0         250
# 397     2001806567  8904223815804        1.0         160
# 398     2001806567  8904223818577        1.0         150
# 399     2001806408  8904223819437        2.0         552
# 400     2001806232  8904223818645        6.0         137
#
# [401 rows x 4 columns]

# %%
X_order.isna().sum()
# Out:
# ExternOrderNo    0
# SKU              0
# Order Qty        0
# Weight (g)       0
# dtype: int64

# %%
X_order['Total weight as per X (KG)']=(X_order['Weight (g)'] /1000)* X_order['Order Qty']
X_order
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)  \
# 0       2001827036  8904223818706        1.0         127
# 1       2001821995  8904223818706        1.0         127
# 2       2001819252  8904223818706        1.0         127
# 3       2001816996  8904223818706        1.0         127
# 4       2001814580  8904223818706        1.0         127
# ..             ...            ...        ...         ...
# 396     2001806616  8904223819123        1.0         250
# 397     2001806567  8904223815804        1.0         160
# 398     2001806567  8904223818577        1.0         150
# 399     2001806408  8904223819437        2.0         552
# 400     2001806232  8904223818645        6.0         137
#
#      Total weight as per X (KG)
# 0                         0.127
# 1                         0.127
# 2                         0.127
# 3                         0.127
# 4                         0.127
# ..                          ...
# 396                       0.250
# ...

# %%
X_order.head(75)
# Out:
#     ExternOrderNo            SKU  Order Qty  Weight (g)  \
# 0      2001827036  8904223818706        1.0         127
# 1      2001821995  8904223818706        1.0         127
# 2      2001819252  8904223818706        1.0         127
# 3      2001816996  8904223818706        1.0         127
# 4      2001814580  8904223818706        1.0         127
# ..            ...            ...        ...         ...
# 70     2001807613  8904223819277        1.0         350
# 71     2001827036  GIFTBOX202002        1.0         500
# 72     2001827036  GIFTBOX202002        1.0         500
# 73     2001827036  8904223818638        2.0         137
# 74     2001825261  8904223818638        3.0         137
#
#     Total weight as per X (KG)
# 0                        0.127
# 1                        0.127
# 2                        0.127
# 3                        0.127
# 4                        0.127
# ..                         ...
# 70                       0.350
# 71                       0.500
# ...

# %%
#X_order['duplicate']=X_order.duplicated()

#X_order.head(77)
# 72  identical
X_order.drop([72],inplace=True)
X_order
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)  \
# 0       2001827036  8904223818706        1.0         127
# 1       2001821995  8904223818706        1.0         127
# 2       2001819252  8904223818706        1.0         127
# 3       2001816996  8904223818706        1.0         127
# 4       2001814580  8904223818706        1.0         127
# ..             ...            ...        ...         ...
# 396     2001806616  8904223819123        1.0         250
# 397     2001806567  8904223815804        1.0         160
# 398     2001806567  8904223818577        1.0         150
# 399     2001806408  8904223819437        2.0         552
# 400     2001806232  8904223818645        6.0         137
#
#      Total weight as per X (KG)
# 0                         0.127
# 1                         0.127
# 2                         0.127
# 3                         0.127
# 4                         0.127
# ..                          ...
# 396                       0.250
# ...

# %%
X_order
# Out:
#      ExternOrderNo            SKU  Order Qty  Weight (g)  \
# 0       2001827036  8904223818706        1.0         127
# 1       2001821995  8904223818706        1.0         127
# 2       2001819252  8904223818706        1.0         127
# 3       2001816996  8904223818706        1.0         127
# 4       2001814580  8904223818706        1.0         127
# ..             ...            ...        ...         ...
# 396     2001806616  8904223819123        1.0         250
# 397     2001806567  8904223815804        1.0         160
# 398     2001806567  8904223818577        1.0         150
# 399     2001806408  8904223819437        2.0         552
# 400     2001806232  8904223818645        6.0         137
#
#      Total weight as per X (KG)
# 0                         0.127
# 1                         0.127
# 2                         0.127
# 3                         0.127
# 4                         0.127
# ..                          ...
# 396                       0.250
# ...

# %%
x_weight=pd.DataFrame(X_order.groupby('ExternOrderNo')['Total weight as per X (KG)'].sum())

x_weight=x_weight.reset_index()
x_weight
# Out:
#      ExternOrderNo  Total weight as per X (KG)
# 0       2001806210                       0.220
# 1       2001806226                       0.480
# 2       2001806229                       0.500
# 3       2001806232                       1.302
# 4       2001806233                       0.245
# ..             ...                         ...
# 119     2001821995                       0.477
# 120     2001822466                       1.376
# 121     2001823564                       0.672
# 122     2001825261                       1.557
# 123     2001827036                       1.676
#
# [124 rows x 2 columns]

# %%
x_weight.rename(columns={'ExternOrderNo':'Order ID'},inplace=True)

# %%
x_weight.head(10)
# Out:
#      Order ID  Total weight as per X (KG)
# 0  2001806210                       0.220
# 1  2001806226                       0.480
# 2  2001806229                       0.500
# 3  2001806232                       1.302
# 4  2001806233                       0.245
# 5  2001806251                       0.245
# 6  2001806273                       0.615
# 7  2001806304                       0.500
# 8  2001806338                       0.500
# 9  2001806408                       2.265

# %%
couriercomp_invoice
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 135.0
# ...

# %%
expresult=couriercomp_invoice[['Order ID','AWB Code']]
expresult
# Out:
#        Order ID       AWB Code
# 0    2001806232  1091117222124
# 1    2001806273  1091117222194
# 2    2001806408  1091117222931
# 3    2001806458  1091117223244
# 4    2001807012  1091117229345
# ..          ...            ...
# 119  2001812941  1091118551656
# 120  2001809383  1091117614452
# 121  2001820978  1091120922803
# 122  2001811475  1091121844806
# 123  2001811305  1091121846136
#
# [124 rows x 2 columns]

# %%
expresult=pd.merge(expresult,x_weight,on='Order ID')
expresult
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
# [124 rows x 3 columns]

# %%
import math

expresult['Weight slab as per X (KG)']=expresult['Total weight as per X (KG)'].apply(lambda x : math.ceil(x*2)/2)
expresult
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
#      Weight slab as per X (KG)
# 0                          1.5
# 1                          1.0
# 2                          2.5
# 3                          1.0
# 4                          0.5
# ..                         ...
# ...

# %%
#x=lambda x : math.ceil(x*2)/2
#x(1.302)

# %%
expresult = pd.merge(expresult, 
                      couriercomp_invoice[['Order ID','Charged Weight']], 
                      on ='Order ID')
expresult
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
#      Weight slab as per X (KG)  Charged Weight
# 0                          1.5            1.30
# 1                          1.0            1.00
# 2                          2.5            2.50
# 3                          1.0            1.00
# ...

# %%
expresult.rename(columns={'Charged Weight':'Total Weight as per courier company(kg)'},inplace=True)

# %%
expresult
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
#      Weight slab as per X (KG)  Total Weight as per courier company(kg)
# 0                          1.5                                     1.30
# 1                          1.0                                     1.00
# ...

# %%
expresult['Weight slab as per courier company(kg)'] = expresult['Total Weight as per courier company(kg)'].apply(lambda x : math.ceil(x*2)/2)
expresult
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
#      Weight slab as per X (KG)  Total Weight as per courier company(kg)  \
# 0                          1.5                                     1.30
# 1                          1.0                                     1.00
# ...

# %%
expresult = pd.merge(expresult, 
                      couriercomp_invoice[['Order ID','Zone']], 
                      on ='Order ID')
expresult
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
#      Weight slab as per X (KG)  Total Weight as per courier company(kg)  \
# 0                          1.5                                     1.30
# 1                          1.0                                     1.00
# ...

# %%
expresult.rename(columns={'Zone':'Delivery zone as per X'},inplace=True)
expresult.head()
# Out:
#      Order ID       AWB Code  Total weight as per X (KG)  \
# 0  2001806232  1091117222124                       1.302
# 1  2001806273  1091117222194                       0.615
# 2  2001806408  1091117222931                       2.265
# 3  2001806458  1091117223244                       0.700
# 4  2001807012  1091117229345                       0.240
#
#    Weight slab as per X (KG)  Total Weight as per courier company(kg)  \
# 0                        1.5                                     1.30
# 1                        1.0                                     1.00
# 2                        2.5                                     2.50
# 3                        1.0                                     1.00
# 4                        0.5                                     0.15
#
#    Weight slab as per courier company(kg) Delivery zone as per X
# 0                                     1.5                      d
# 1                                     1.0                      d
# ...

# %%
# Delivery zone charge by courier company

expresult['Delivery zone charge by courier company'] = expresult['Delivery zone as per X']
expresult.head()
# Out:
#      Order ID       AWB Code  Total weight as per X (KG)  \
# 0  2001806232  1091117222124                       1.302
# 1  2001806273  1091117222194                       0.615
# 2  2001806408  1091117222931                       2.265
# 3  2001806458  1091117223244                       0.700
# 4  2001807012  1091117229345                       0.240
#
#    Weight slab as per X (KG)  Total Weight as per courier company(kg)  \
# 0                        1.5                                     1.30
# 1                        1.0                                     1.00
# 2                        2.5                                     2.50
# 3                        1.0                                     1.00
# 4                        0.5                                     0.15
#
#    Weight slab as per courier company(kg) Delivery zone as per X  \
# 0                                     1.5                      d
# 1                                     1.0                      d
# ...

# %%
#Calcuation of 'Expected charges as per X'

# creating the dataframe having 'Order ID','Weight slab as per X(kg)','Delivery zone as per X'

calculation =pd.DataFrame(expresult[['Order ID','Weight slab as per X (KG)','Delivery zone as per X']])
calculation
# Out:
#        Order ID  Weight slab as per X (KG) Delivery zone as per X
# 0    2001806232                        1.5                      d
# 1    2001806273                        1.0                      d
# 2    2001806408                        2.5                      d
# 3    2001806458                        1.0                      b
# 4    2001807012                        0.5                      d
# ..          ...                        ...                    ...
# 119  2001812941                        0.5                      d
# 120  2001809383                        1.0                      d
# 121  2001820978                        1.0                      d
# 122  2001811475                        1.0                      b
# 123  2001811305                        1.0                      d
#
# [124 rows x 3 columns]

# %%
calculation = pd.merge(calculation, 
                      couriercomp_invoice[['Order ID','Type of Shipment']], 
                      on ='Order ID')

calculation.head()
# Out:
#      Order ID  Weight slab as per X (KG) Delivery zone as per X  \
# 0  2001806232                        1.5                      d
# 1  2001806273                        1.0                      d
# 2  2001806408                        2.5                      d
# 3  2001806458                        1.0                      b
# 4  2001807012                        0.5                      d
#
#   Type of Shipment
# 0  Forward charges
# 1  Forward charges
# 2  Forward charges
# 3  Forward charges
# 4  Forward charges

# %%
couriercomp_Rate
# Out:
#    fwd_a_fixed  fwd_a_additional  fwd_b_fixed  fwd_b_additional  fwd_c_fixed  \
# 0         29.5              23.6           33              28.3         40.1
#
#    fwd_c_additional  fwd_d_fixed  fwd_d_additional  fwd_e_fixed  \
# 0              38.9         45.4              44.8         56.6
#
#    fwd_e_additional  rto_a_fixed  rto_a_additional  rto_b_fixed  \
# 0              55.5         13.6              23.6         20.5
#
#    rto_b_additional  rto_c_fixed  rto_c_additional  rto_d_fixed  \
# 0              28.3         31.9              38.9         41.3
#
#    rto_d_additional  rto_e_fixed  rto_e_additional
# 0              44.8         50.7              55.5

# %%
calculation['Expected charge as per X(Rs)']=0

# %%
calculation
# Out:
#        Order ID  Weight slab as per X (KG) Delivery zone as per X  \
# 0    2001806232                        1.5                      d
# 1    2001806273                        1.0                      d
# 2    2001806408                        2.5                      d
# 3    2001806458                        1.0                      b
# 4    2001807012                        0.5                      d
# ..          ...                        ...                    ...
# 119  2001812941                        0.5                      d
# 120  2001809383                        1.0                      d
# 121  2001820978                        1.0                      d
# 122  2001811475                        1.0                      b
# 123  2001811305                        1.0                      d
#
#             Type of Shipment  Expected charge as per X(Rs)
# 0            Forward charges                             0
# ...

# %%
for i in range(0,123):
    
    if ((calculation['Delivery zone as per X'][i]=='d') and (calculation['Type of Shipment'][i]=='Forward charges')):
        calculation['Expected charge as per X(Rs)'][i] = couriercomp_Rate['fwd_d_fixed'] + ((calculation['Weight slab as per X (KG)'][i]/0.5)-1)*couriercomp_Rate['fwd_d_additional'][0]
        
    elif ((calculation['Delivery zone as per X'][i]=='d') and (calculation['Type of Shipment'][i]=='Forward and RTO charges')):
        calculation['Expected charge as per X(Rs)'][i] = couriercomp_Rate['fwd_d_fixed'][0] + ((calculation['Weight slab as per X (KG)'][i]/0.5)-1)*couriercomp_Rate['fwd_d_additional'][0] + couriercomp_Rate['rto_d_fixed'][0] 
        
    elif ((calculation['Delivery zone as per X'][i]=='b') and (calculation['Type of Shipment'][i]=='Forward charges')):
        calculation['Expected charge as per X(Rs)'][i] = couriercomp_Rate['fwd_b_fixed'][0] + ((calculation['Weight slab as per X (KG)'][i]/0.5)-1)*couriercomp_Rate['fwd_b_additional'][0]
        
    elif ((calculation['Delivery zone as per X'][i]=='b') and (calculation['Type of Shipment'][i]=='Forward and RTO charges')):
        calculation['Expected charge as per X(Rs)'][i] = couriercomp_Rate['fwd_b_fixed'][0] + ((calculation['Weight slab as per X (KG)'][i]/0.5)-1)*couriercomp_Rate['fwd_d_additional'][0] + couriercomp_Rate['rto_b_fixed'][0] + ((calculation['Weight slab as per X (KG)'][i]/0.5)-1)*couriercomp_Rate['rto_b_additional'][0]
        
    elif ((calculation['Delivery zone as per X'][i]=='e') and (calculation['Type of Shipment'][i]=='Forward charges')):
        calculation['Expected charge as per X(Rs)'][i] = couriercomp_Rate['fwd_e_fixed'][0] + ((calculation['Weight slab as per X (KG)'][i]/0.5)-1)*couriercomp_Rate['fwd_e_additional'][0]
        
    elif ((calculation['Delivery zone as per X'][i]=='e') and (calculation['Type of Shipment'][i]=='Forward and RTO charges')):
        calculation['Expected charge as per X(Rs)'][i] = couriercomp_Rate['fwd_e_fixed'][0] + ((calculation['Weight slab as per X (KG)'][i]/0.5)-1)*couriercomp_Rate['fwd_e_additional'][0] + couriercomp_Rate['rto_e_fixed'][0] + ((calculation['Weight slab as per X (KG)'][i]/0.5)-1)*couriercomp_Rate['rto_e_additional'][0]
        
    calculation['Expected charge as per X(Rs)'].append(calculation['Expected charge as per X(Rs)'])
# Out:
# C:\Users\L\AppData\Local\Temp\ipykernel_9260\3619951781.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   calculation['Expected charge as per X(Rs)'][i] = couriercomp_Rate['fwd_d_fixed'] + ((calculation['Weight slab as per X (KG)'][i]/0.5)-1)*couriercomp_Rate['fwd_d_additional'][0]
# C:\Users\L\AppData\Local\Temp\ipykernel_9260\3619951781.py:21: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   calculation['Expected charge as per X(Rs)'].append(calculation['Expected charge as per X(Rs)'])
# C:\Users\L\AppData\Local\Temp\ipykernel_9260\3619951781.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
calculation['Expected charge as per X(Rs)']
# Out:
# 0      135.0
# 1        NaN
# 2      224.6
# 3       61.3
# 4       45.4
#        ...
# 119     45.4
# 120    131.5
# 121     90.2
# 122     61.3
# 123      0.0
# Name: Expected charge as per X(Rs), Length: 124, dtype: float64

# %%
couriercomp_invoice
# Out:
#           AWB Code    Order ID  Charged Weight  Warehouse Pincode  \
# 0    1091117222124  2001806232            1.30             121003
# 1    1091117222194  2001806273            1.00             121003
# 2    1091117222931  2001806408            2.50             121003
# 3    1091117223244  2001806458            1.00             121003
# 4    1091117229345  2001807012            0.15             121003
# ..             ...         ...             ...                ...
# 119  1091118551656  2001812941            0.73             121003
# 120  1091117614452  2001809383            0.50             121003
# 121  1091120922803  2001820978            0.50             121003
# 122  1091121844806  2001811475            0.50             121003
# 123  1091121846136  2001811305            0.50             121003
#
#      Customer Pincode Zone         Type of Shipment  Billing Amount (Rs.)
# 0              507101    d          Forward charges                 135.0
# ...

# %%
expresult = pd.merge(expresult, 
                      calculation[['Order ID','Expected charge as per X(Rs)']], 
                      on ='Order ID')

expresult.head()
# Out:
#      Order ID       AWB Code  Total weight as per X (KG)  \
# 0  2001806232  1091117222124                       1.302
# 1  2001806273  1091117222194                       0.615
# 2  2001806408  1091117222931                       2.265
# 3  2001806458  1091117223244                       0.700
# 4  2001807012  1091117229345                       0.240
#
#    Weight slab as per X (KG)  Total Weight as per courier company(kg)  \
# 0                        1.5                                     1.30
# 1                        1.0                                     1.00
# 2                        2.5                                     2.50
# 3                        1.0                                     1.00
# 4                        0.5                                     0.15
#
#    Weight slab as per courier company(kg) Delivery zone as per X  \
# 0                                     1.5                      d
# 1                                     1.0                      d
# ...

# %%
expresult = pd.merge(expresult, 
                      couriercomp_invoice[['Order ID','Billing Amount (Rs.)']], 
                      on ='Order ID')
expresult
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
#      Weight slab as per X (KG)  Total Weight as per courier company(kg)  \
# 0                          1.5                                     1.30
# 1                          1.0                                     1.00
# ...

# %%
# Renaming the column

expresult.rename(columns={'Billing Amount (Rs.)':'Charged billed by courier company(Rs)'},inplace=True)
expresult.head()
# Out:
#      Order ID       AWB Code  Total weight as per X (KG)  \
# 0  2001806232  1091117222124                       1.302
# 1  2001806273  1091117222194                       0.615
# 2  2001806408  1091117222931                       2.265
# 3  2001806458  1091117223244                       0.700
# 4  2001807012  1091117229345                       0.240
#
#    Weight slab as per X (KG)  Total Weight as per courier company(kg)  \
# 0                        1.5                                     1.30
# 1                        1.0                                     1.00
# 2                        2.5                                     2.50
# 3                        1.0                                     1.00
# 4                        0.5                                     0.15
#
#    Weight slab as per courier company(kg) Delivery zone as per X  \
# 0                                     1.5                      d
# 1                                     1.0                      d
# ...

# %%
expresult['Difference between expected charges and billed charges(Rs)'] = round(expresult['Expected charge as per X(Rs)']-expresult['Charged billed by courier company(Rs)'],3)
expresult
# Out:
#        Order ID       AWB Code  Total weight as per X (KG)  \
# 0    2001806232  1091117222124                       1.302
# 1    2001806273  1091117222194                       0.615
# 2    2001806408  1091117222931                       2.265
# 3    2001806458  1091117223244                       0.700
# 4    2001807012  1091117229345                       0.240
# ..          ...            ...                         ...
# 119  2001812941  1091118551656                       0.500
# 120  2001809383  1091117614452                       0.607
# 121  2001820978  1091120922803                       0.515
# 122  2001811475  1091121844806                       0.689
# 123  2001811305  1091121846136                       0.750
#
#      Weight slab as per X (KG)  Total Weight as per courier company(kg)  \
# 0                          1.5                                     1.30
# 1                          1.0                                     1.00
# ...

# %%
expresult.to_excel("ExpResults1.xlsx")

# %%
count=expresult[expresult['Difference between expected charges and billed charges(Rs)']==0].count()['Difference between expected charges and billed charges(Rs)']
count
# Out:
# 52

# %%
# Count of Total Orders - Over Charged

courier=expresult[expresult['Difference between expected charges and billed charges(Rs)']<0].count()['Difference between expected charges and billed charges(Rs)']
courier
# Out:
# 60

# %%
# Count of Total Orders - Under Charged

countoftotalor=expresult[expresult['Difference between expected charges and billed charges(Rs)']>0].count()['Difference between expected charges and billed charges(Rs)']
countoftotalor
# Out:
# 11

# %%
# sum of Total Orders - Correctly Charged

sumofcorrect=round(expresult[expresult['Difference between expected charges and billed charges(Rs)']==0].sum()['Expected charge as per X(Rs)'],2)
sumofcorrect
# Out:
# 4512.3

# %%
# sum of Total Orders - Over Charged

sumoforders=round(expresult[expresult['Difference between expected charges and billed charges(Rs)']<0].sum()['Expected charge as per X(Rs)'],2)
sumoforders
# Out:
# 3996.8

# %%
# sum of Total Orders - Under Charged

sumofordersuc=round(expresult[expresult['Difference between expected charges and billed charges(Rs)']>0].sum()['Expected charge as per X(Rs)'],2)
sumofordersuc
# Out:
# 1753.7

# %%
data = {'Count': [count,courier,countoftotalor],
        'Sum': [sumofcorrect,sumoforders,sumofordersuc]}

# %%
   

Summary = pd.DataFrame(data, index=['Total Orders - Correctly Charged','Total Orders - Over Charged','Total Orders - Under Charged'])
Summary
# Out:
#                                   Count     Sum
# Total Orders - Correctly Charged     52  4512.3
# Total Orders - Over Charged          60  3996.8
# Total Orders - Under Charged         11  1753.7

# %%
# store
Summary.to_excel("summary.xlsx")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Input In [49], in <cell line: 2>()
#       1 # store
# ----> 2 Summary.to_excel("summary.xlsx")
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
# ...
